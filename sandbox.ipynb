# %% [markdown]
# # ML Sandbox
#
# Freeform experimentation space. No rules, no structure - just play.
#
# Use this notebook to:
# - Try out ideas before adding them to modules
# - Experiment with different approaches
# - Break things and see what happens
# - Quick scratch work

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-darkgrid')
# %matplotlib inline

print("Sandbox ready. Go experiment!")

# %%
# Your experiments here...
